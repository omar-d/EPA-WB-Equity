# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import wbdata

# %% [markdown]
# # Child marriage
#
# Chil marriage over the past years (2007-2017), has child marriage dropped? (marriage before 15 and marriage before 18 (data checking/ fact checking) and if this rate contineous, will goal 5.3 be reached in 2030?(extrapoleren):
#     - Child marriage percentage per country over time
#         -How was it in the past
#         -how is it now
#         -how will it develop over time
#     - marriage before 15
#     - marriage before 18
#     - woman who have to obey their husband by law

# %% [markdown]
# Child marriage per country over time

# %% [markdown]
# Data about child marriage from the past. This data shows the perecentage of women who were first married by age 18.

# %%
# married18_all = pd.DataFrame(wbdata.get_data("SP.M18.2024.FE.ZS"))
# married18_all['country'] = married18_all.country.astype(str).str.slice(23,-2)
# married18_all['indicator'] = married18_all.indicator.astype(str).str.slice(35,-2)
# married18_all['value'] = married18_all.value.astype(float).round(1)
# married18 = married18.loc[married18["value"] >= 0]
# married18

# %% [markdown]
# #### Deze data laat zien hoe het er nu voor staat met het aantal child marriages

# %% [markdown]
# This data shows the percentage of women who were first married by the age of 15.

# %%
married15_all = pd.DataFrame(wbdata.get_data("SP.M15.2024.FE.ZS"))
married15_all['country'] = married15_all.country.astype(str).str.slice(23,-2)
married15_all['indicator'] = married15_all.indicator.astype(str).str.slice(35,-2)
married15_all['value'] = married15_all.value.astype(float).round(1)


#find rows where the value is greater than 0
married15_0 = married15_all.loc[(married15_all["value"] >= 0)]

#find the rows with the most recent data
married15 = married15_0.sort_values("date", ascending = False).drop_duplicates(["country"])
married15["data"] = married15.value.astype(str)
married15
# Out:
#                         country  date decimal  \
# 7889                      India  2016       2
# 3017                     Angola  2016       2
# 3191                    Armenia  2016       2
# 10789                     Nepal  2016       2
# 9687                     Malawi  2016       2
# 13805                  Tanzania  2016       2
# 6439                   Ethiopia  2016       2
# 10615                   Myanmar  2016       2
# 12413                   Senegal  2016       2
# 2728                Afghanistan  2015       2
# 5164                   Colombia  2015       2
# 7368                  Guatemala  2015       2
# 4932                       Chad  2015       2
# 12124                    Rwanda  2015       2
# 15256                  Zimbabwe  2015       2
# 4643                   Cambodia  2014       2
# 6093           Egypt, Arab Rep.  2014       2
# 8587                      Kenya  2014       2
# 7021                      Ghana  2014       2
# 14003                      Togo  2014       2
# 15199                    Zambia  2014       2
# 9167                    Lesotho  2014       2
# 5281           Congo, Dem. Rep.  2014       2
# 3599                 Bangladesh  2014       2
# 9864                       Mali  2013       2
# 6004         Dominican Republic  2013       2
# 11720               Philippines  2013       2
# 12590              Sierra Leone  2013       2
# 11372                  Pakistan  2013       2
# 6848                Gambia, The  2013       2
# ...                         ...   ...     ...
# 2792                    Albania  2009       2
# 9810                   Maldives  2009       2
# 7548                     Guyana  2009       2
# 4069                    Bolivia  2008       2
# 6390                   Eswatini  2007       2
# 14510                   Ukraine  2007       2
# 3433                 Azerbaijan  2006       2
# 10278                   Moldova  2005       2
# 15012                   Vietnam  2005       2
# 10511                   Morocco  2004       2
# 14224                    Turkey  2003       2
# 6279                    Eritrea  2002       2
# 10050                Mauritania  2001       2
# 11036                 Nicaragua  2001       2
# 14285              Turkmenistan  2000       2
# 8544                 Kazakhstan  1999       2
# 13019              South Africa  1998       2
# 14811                Uzbekistan  1996       2
# 4255                     Brazil  1996       2
# 4894   Central African Republic  1995       2
# 13483                     Sudan  1990       2
# 11627                  Paraguay  1990       2
# 4205                   Botswana  1988       2
# 14181                   Tunisia  1988       2
# 10180                    Mexico  1987       2
# 6062                    Ecuador  1987       2
# 13892                  Thailand  1987       2
# 14124       Trinidad and Tobago  1987       2
# 13196                 Sri Lanka  1987       2
# 6180                El Salvador  1985       2
#
#                                                indicator  value  data
# 7889   : 'Women who were first married by age 15 (% o...    5.4   5.4
# 3017   : 'Women who were first married by age 15 (% o...    7.9   7.9
# 3191   : 'Women who were first married by age 15 (% o...    0.0   0.0
# 10789  : 'Women who were first married by age 15 (% o...    7.0   7.0
# 9687   : 'Women who were first married by age 15 (% o...    9.0   9.0
# 13805  : 'Women who were first married by age 15 (% o...    5.2   5.2
# 6439   : 'Women who were first married by age 15 (% o...   14.1  14.1
# 10615  : 'Women who were first married by age 15 (% o...    1.9   1.9
# 12413  : 'Women who were first married by age 15 (% o...    7.9   7.9
# 2728   : 'Women who were first married by age 15 (% o...    8.8   8.8
# 5164   : 'Women who were first married by age 15 (% o...    4.9   4.9
# 7368   : 'Women who were first married by age 15 (% o...    6.2   6.2
# 4932   : 'Women who were first married by age 15 (% o...   29.7  29.7
# 12124  : 'Women who were first married by age 15 (% o...    0.4   0.4
# 15256  : 'Women who were first married by age 15 (% o...    3.7   3.7
# 4643   : 'Women who were first married by age 15 (% o...    1.9   1.9
# 6093   : 'Women who were first married by age 15 (% o...    2.0   2.0
# 8587   : 'Women who were first married by age 15 (% o...    4.4   4.4
# 7021   : 'Women who were first married by age 15 (% o...    4.9   4.9
# 14003  : 'Women who were first married by age 15 (% o...    5.5   5.5
# 15199  : 'Women who were first married by age 15 (% o...    5.9   5.9
# 9167   : 'Women who were first married by age 15 (% o...    1.0   1.0
# 5281   : 'Women who were first married by age 15 (% o...   10.0  10.0
# 3599   : 'Women who were first married by age 15 (% o...   22.4  22.4
# 9864   : 'Women who were first married by age 15 (% o...   22.8  22.8
# 6004   : 'Women who were first married by age 15 (% o...   10.2  10.2
# 11720  : 'Women who were first married by age 15 (% o...    2.0   2.0
# 12590  : 'Women who were first married by age 15 (% o...   12.5  12.5
# 11372  : 'Women who were first married by age 15 (% o...    2.8   2.8
# 6848   : 'Women who were first married by age 15 (% o...    9.3   9.3
# ...                                                  ...    ...   ...
# 2792   : 'Women who were first married by age 15 (% o...    0.2   0.2
# 9810   : 'Women who were first married by age 15 (% o...    0.3   0.3
# 7548   : 'Women who were first married by age 15 (% o...    5.5   5.5
# 4069   : 'Women who were first married by age 15 (% o...    3.2   3.2
# 6390   : 'Women who were first married by age 15 (% o...    1.0   1.0
# 14510  : 'Women who were first married by age 15 (% o...    0.2   0.2
# 3433   : 'Women who were first married by age 15 (% o...    0.7   0.7
# 10278  : 'Women who were first married by age 15 (% o...    0.5   0.5
# 15012  : 'Women who were first married by age 15 (% o...    0.5   0.5
# 10511  : 'Women who were first married by age 15 (% o...    2.5   2.5
# 14224  : 'Women who were first married by age 15 (% o...    2.2   2.2
# 6279   : 'Women who were first married by age 15 (% o...   19.6  19.6
# 10050  : 'Women who were first married by age 15 (% o...   20.8  20.8
# 11036  : 'Women who were first married by age 15 (% o...   13.3  13.3
# 14285  : 'Women who were first married by age 15 (% o...    0.0   0.0
# 8544   : 'Women who were first married by age 15 (% o...    0.3   0.3
# 13019  : 'Women who were first married by age 15 (% o...    1.1   1.1
# 14811  : 'Women who were first married by age 15 (% o...    0.4   0.4
# 4255   : 'Women who were first married by age 15 (% o...    4.4   4.4
# 4894   : 'Women who were first married by age 15 (% o...   19.6  19.6
# 13483  : 'Women who were first married by age 15 (% o...   11.5  11.5
# 11627  : 'Women who were first married by age 15 (% o...    3.1   3.1
# 4205   : 'Women who were first married by age 15 (% o...    2.5   2.5
# 14181  : 'Women who were first married by age 15 (% o...    0.5   0.5
# 10180  : 'Women who were first married by age 15 (% o...    6.2   6.2
# 6062   : 'Women who were first married by age 15 (% o...    5.8   5.8
# 13892  : 'Women who were first married by age 15 (% o...    2.4   2.4
# 14124  : 'Women who were first married by age 15 (% o...    6.0   6.0
# 13196  : 'Women who were first married by age 15 (% o...    1.1   1.1
# 6180   : 'Women who were first married by age 15 (% o...    6.2   6.2
#
# [86 rows x 6 columns]

# %% [markdown]
# Because we only look at the top 15 countries with the lowest equality rate. A new dataframe is made only containing the countries with this low equality rate compared.

# %%
CPIA_worst15 = pd.read_csv("CPIA_worst15.csv")
CPIA_worst15["date"] = CPIA_worst15["date"].astype(str)

# %%
married15_worst15 = pd.merge( CPIA_worst15,married15, how = "left", left_on = ["country"], right_on = ["country"])
married15_worst15
# Out:
#     Unnamed: 0                   country date_x  decimal_x  \
# 0        15138               Yemen, Rep.   2017          1
# 1        12934                   Somalia   2017          1
# 2         7482             Guinea-Bissau   2017          1
# 3        13050               South Sudan   2017          1
# 4         9860                      Mali   2017          1
# 5         6264                   Eritrea   2017          1
# 6        11078                     Niger   2017          1
# 7         8642                  Kiribati   2017          1
# 8         5278          Congo, Dem. Rep.   2017          1
# 9         4930                      Chad   2017          1
# 10        4872  Central African Republic   2017          1
# 11       13456                     Sudan   2017          1
# 12       10208     Micronesia, Fed. Sts.   2017          1
# 13        7598                     Haiti   2017          1
# 14       11542          Papua New Guinea   2017          1
#
#                                       indicator_x  value_x country_code  \
# 0   CPIA gender equality rating (1=low to 6=high)      1.5           YE
# 1   CPIA gender equality rating (1=low to 6=high)      2.0           SO
# 2   CPIA gender equality rating (1=low to 6=high)      2.0           GW
# 3   CPIA gender equality rating (1=low to 6=high)      2.0           SS
# 4   CPIA gender equality rating (1=low to 6=high)      2.5           ML
# 5   CPIA gender equality rating (1=low to 6=high)      2.5           ER
# 6   CPIA gender equality rating (1=low to 6=high)      2.5           NE
# 7   CPIA gender equality rating (1=low to 6=high)      2.5           KI
# 8   CPIA gender equality rating (1=low to 6=high)      2.5           CD
# 9   CPIA gender equality rating (1=low to 6=high)      2.5           TD
# 10  CPIA gender equality rating (1=low to 6=high)      2.5           CF
# 11  CPIA gender equality rating (1=low to 6=high)      2.5           SD
# 12  CPIA gender equality rating (1=low to 6=high)      2.5           FM
# 13  CPIA gender equality rating (1=low to 6=high)      2.5           HT
# 14  CPIA gender equality rating (1=low to 6=high)      2.5           PG
#
#    date_y decimal_y                                        indicator_y  \
# 0    2013         2  : 'Women who were first married by age 15 (% o...
# 1     NaN       NaN                                                NaN
# 2     NaN       NaN                                                NaN
# 3     NaN       NaN                                                NaN
# 4    2013         2  : 'Women who were first married by age 15 (% o...
# 5    2002         2  : 'Women who were first married by age 15 (% o...
# 6    2012         2  : 'Women who were first married by age 15 (% o...
# 7     NaN       NaN                                                NaN
# 8    2014         2  : 'Women who were first married by age 15 (% o...
# 9    2015         2  : 'Women who were first married by age 15 (% o...
# 10   1995         2  : 'Women who were first married by age 15 (% o...
# 11   1990         2  : 'Women who were first married by age 15 (% o...
# 12    NaN       NaN                                                NaN
# 13   2012         2  : 'Women who were first married by age 15 (% o...
# 14    NaN       NaN                                                NaN
#
#     value_y  data
# 0       9.4   9.4
# 1       NaN   NaN
# 2       NaN   NaN
# 3       NaN   NaN
# 4      22.8  22.8
# 5      19.6  19.6
# 6      28.0  28.0
# 7       NaN   NaN
# 8      10.0  10.0
# 9      29.7  29.7
# 10     19.6  19.6
# 11     11.5  11.5
# 12      NaN   NaN
# 13      2.8   2.8
# 14      NaN   NaN

# %%
married15_worst15.plot(kind="bar", x = "country", y = "value_y", legend = False)

plt.title("Percentage of women who were first married by the age of 15")
plt.xlabel("Country")
plt.ylabel("Percentage")
# Out:
# Text(0,0.5,'Percentage')

# %%
# missing values aanvullen met een andere database?
# visualiseren dat de data van married 15 van sommige landen niet recent is.

# %% [markdown]
# #### Data van vroeger tot nu

# %%
# married15_0 gebruiken om te kunnen laten zien hoe het aantal kindhuwelijken over de jaren heen is veranderd

married15_past = married15_0.loc[((married15_0["country"].isin(CPIA_worst15["country"]))),:]

married15_past
# Out:
#                         country  date decimal  \
# 4894   Central African Republic  1995       2
# 4932                       Chad  2015       2
# 4943                       Chad  2004       2
# 4950                       Chad  1997       2
# 5281           Congo, Dem. Rep.  2014       2
# 5288           Congo, Dem. Rep.  2007       2
# 6279                    Eritrea  2002       2
# 6286                    Eritrea  1995       2
# 7603                      Haiti  2012       2
# 7609                      Haiti  2006       2
# 7615                      Haiti  2000       2
# 7620                      Haiti  1995       2
# 9864                       Mali  2013       2
# 9871                       Mali  2006       2
# 9876                       Mali  2001       2
# 9881                       Mali  1996       2
# 9890                       Mali  1987       2
# 11083                     Niger  2012       2
# 11089                     Niger  2006       2
# 11097                     Niger  1998       2
# 11103                     Niger  1992       2
# 13483                     Sudan  1990       2
# 15142               Yemen, Rep.  2013       2
# 15158               Yemen, Rep.  1997       2
# 15163               Yemen, Rep.  1992       2
#
#                                                indicator  value
# 4894   : 'Women who were first married by age 15 (% o...   19.6
# 4932   : 'Women who were first married by age 15 (% o...   29.7
# 4943   : 'Women who were first married by age 15 (% o...   34.5
# 4950   : 'Women who were first married by age 15 (% o...   28.6
# 5281   : 'Women who were first married by age 15 (% o...   10.0
# 5288   : 'Women who were first married by age 15 (% o...    8.3
# 6279   : 'Women who were first married by age 15 (% o...   19.6
# 6286   : 'Women who were first married by age 15 (% o...   18.2
# 7603   : 'Women who were first married by age 15 (% o...    2.8
# 7609   : 'Women who were first married by age 15 (% o...    5.6
# 7615   : 'Women who were first married by age 15 (% o...    5.3
# 7620   : 'Women who were first married by age 15 (% o...    4.8
# 9864   : 'Women who were first married by age 15 (% o...   22.8
# 9871   : 'Women who were first married by age 15 (% o...   24.6
# 9876   : 'Women who were first married by age 15 (% o...   24.5
# 9881   : 'Women who were first married by age 15 (% o...   19.2
# 9890   : 'Women who were first married by age 15 (% o...   27.1
# 11083  : 'Women who were first married by age 15 (% o...   28.0
# 11089  : 'Women who were first married by age 15 (% o...   36.1
# 11097  : 'Women who were first married by age 15 (% o...   35.1
# 11103  : 'Women who were first married by age 15 (% o...   50.3
# 13483  : 'Women who were first married by age 15 (% o...   11.5
# 15142  : 'Women who were first married by age 15 (% o...    9.4
# 15158  : 'Women who were first married by age 15 (% o...   14.0
# 15163  : 'Women who were first married by age 15 (% o...   20.4

# %% [markdown]
# #### Deze landen missen in married 15!
# 1                      Somalia
# 2                Guinea-Bissau
# 3                  South Sudan
# 7                     Kiribati
# 12       Micronesia, Fed. Sts.
# 14            Papua New Guinea

# %%
married15_past["date"] = married15_past["date"].astype(int)

married15_past.loc[married15_past["country"] == "Mali"].plot(x = "date", y = "value")
# Out:
# C:\Users\veram\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# #### Interpoleren

# %%
date = married15_past.loc[married15_past["country"] == "Mali"]["date"].values
value =  married15_past.loc[married15_past["country"] == "Mali"]["value"].values

np.interp(2001, 'date', 'value')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-f47618ec190f> in <module>()
#       2 value =  married15_past.loc[married15_past["country"] == "Mali"]["value"].values
#       3
# ----> 4 np.interp(2001, 'date', 'value')
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in interp(x, xp, fp, left, right, period)
#    2055     if period is None:
#    2056         if isinstance(x, (float, int, number)):
# -> 2057             return interp_func([x], xp, fp, left, right).item()
#    2058         elif isinstance(x, np.ndarray) and x.ndim == 0:
#    2059             return interp_func([x], xp, fp, left, right).item()
#
# ValueError: object of too small depth for desired array

# %% [markdown]
# #### Extrapoleren

# %%
# make array out of dataframe
date = married15_past.loc[married15_past["country"] == "Mali"]["date"].values
value =  married15_past.loc[married15_past["country"] == "Mali"]["value"].values

z = np.polyval((np.polyfit(married15_past["date"], married15_past["value"], 10)), 10)
new_value = np.append(value, z)

plt.plot(date, value)
# Out:
# C:\Users\veram\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RankWarning: Polyfit may be poorly conditioned
#   """
